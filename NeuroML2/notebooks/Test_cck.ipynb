# %% [markdown]
# ## CCK+ basket cell
#
# This notebook presents a quick overview (input current sweeps, f-I curve, morphology) of the CCK+ basket cell model presented in [Bezaire et al. 2016](https://elifesciences.org/articles/18566). Original code in NEURON [ModelDB:187604](https://senselab.med.yale.edu/ModelDB/ShowModel.cshtml?model=187604) - converted to NeuroML by András Ecker and Padraig Gleeson (last update: 07.2017)
# > Note: to use the notebook one has to install [pyNeuroML](https://github.com/NeuroML/pyNeuroML)

# %%
# %autoreload 2
# %matplotlib inline
# Out:
# ERROR:root:Line magic function `%autoreload` not found.

# %% [markdown]
# ### Reproduce original NEURON version
#
# * Summary about the original version of the cell can be found at [mariannebezaire.com](http://mariannebezaire.com/ca1_graphic/celltype.html#cckcell)
# * The cell below reproduces the "current sweep" figure

# %%
from helper import input_currents
cell_file = "../cells/cck.cell.nml"

input_currents(cell_file,
               custom_amps_nA=[-0.1, -0.08, -0.06, -0.04, -0.02, 0.0, 0.08],
               analysis_duration=600,
               pre_zero_pulse=50,
               post_zero_pulse=50)
# Out:
# pyNeuroML >>> Generating an IF curve for cell cckcell in ../cells/cck.cell.nml using jNeuroML_NEURON ['-0.1nA', '-0.08nA', '-0.06nA', '-0.04nA', '-0.02nA', '0.0nA', '0.08nA']
# pyNeuroML >>> Written LEMS Simulation iv_cckcell to file: LEMS_iv_cckcell.xml
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# pyNeuroML >>> Generating plot: Membrane potential traces for: ../cells/cck.cell.nml
# pyNeuroML >>> Saved image to figures/cckcell_traces.png of plot: Membrane potential traces for: ../cells/cck.cell.nml

# %% [markdown]
# * The cell below reproduces the "firing rate" figure

# %%
from helper import fI_curve

fI_curve(cell_file)
# Out:
# pyNeuroML >>> Generating an IF curve for cell cckcell in ../cells/cck.cell.nml using jNeuroML_NEURON (-0.1nA->0.4nA; 25 steps of 0.02nA)
# pyNeuroML >>> Written LEMS Simulation iv_cckcell to file: LEMS_iv_cckcell.xml
# pyNeuroML >>> Generating plot: Firing frequency versus injected current for: ../cells/cck.cell.nml
# pyNeuroML >>> Saved image to figures/cckcell_fI.png of plot: Firing frequency versus injected current for: ../cells/cck.cell.nml

# %% [markdown]
# * The cell below shows the morphology of the cell (NeuroML version matching the NEURON version)

# %%
from pyneuroml import pynml
from IPython.display import Image

pynml.run_jneuroml("", cell_file, '-png')
Image(filename=cell_file.replace('.nml','.png'),width=500)
