# %%
# %matplotlib inline  
import sys
from pyneuroml.analysis import generate_current_vs_frequency_curve

cell_file = "../cells/ivy.cell.nml"
cell_id = "ivycell"

curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    custom_amps_nA =       [-0.14, -0.12, -0.1, -0.08, -0.06, -0.04, -0.02, 0, 0.84], 
                                    analysis_duration =    1000, 
                                    pre_zero_pulse =       500,
                                    post_zero_pulse =      1000,
                                    analysis_delay =       0,
                                    dt =                   0.025,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  True,
                                    plot_if =              False,
                                    plot_iv =              False,
                                    temperature =          '34degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell ivycell in ../cells/ivy.cell.nml using jNeuroML_NEURON (-0.1nA->0.1nA; 0.01nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_ivycell to file: LEMS_iv_ivycell.xml
# pyNeuroML >>> Generating plot: Membrane potential traces for: ../cells/ivy.cell.nml

# %%
# Longer duration, more points 
    
curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    start_amp_nA =         -0.1, 
                                    end_amp_nA =           0.4, 
                                    step_nA =              0.02, 
                                    analysis_duration =    1000, ######### 2000
                                    pre_zero_pulse =       0,
                                    post_zero_pulse =      0,
                                    analysis_delay =       100,
                                    dt =                   0.025,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  False,
                                    plot_if =              True,
                                    plot_iv =              True,
                                    temperature =          '34degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell ivycell in ../cells/ivy.cell.nml using jNeuroML_NEURON (-0.1nA->0.4nA; 0.02nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_ivycell to file: LEMS_iv_ivycell.xml
# pyNeuroML >>> Generating plot: Firing frequency versus injected current for: ../cells/ivy.cell.nml
# pyNeuroML >>> Generating plot: V at 1100ms versus I below threshold for: ../cells/ivy.cell.nml

# %%
from pyneuroml import pynml
pynml.run_jneuroml("", cell_file, '-png')
from IPython.display import Image
Image(filename=cell_file.replace('.nml','.png'),width=500)
