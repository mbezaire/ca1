# %%
# %matplotlib inline  
import sys
from pyneuroml.analysis import generate_current_vs_frequency_curve

cell_file = "../cells/axoaxonic.cell.nml"
cell_id = "axoaxoniccell"

curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    custom_amps_nA =       [-0.2, -0.15, -0.1, -0.05, 0, 0.5], 
                                    analysis_duration =    1000, 
                                    pre_zero_pulse =       500,
                                    post_zero_pulse =      500,
                                    analysis_delay =       0,
                                    dt =                   0.025,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  True,
                                    plot_if =              False,
                                    plot_iv =              False,
                                    temperature =          '34degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell axoaxoniccell in ../cells/axoaxonic.cell.nml using jNeuroML_NEURON (-0.1nA->0.1nA; 0.01nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_axoaxoniccell to file: LEMS_iv_axoaxoniccell.xml
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# pyNeuroML >>> Generating plot: Membrane potential traces for: ../cells/axoaxonic.cell.nml

# %%
# Longer duration, more points 
    
curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    start_amp_nA =         -0.1, 
                                    end_amp_nA =           0.4, 
                                    step_nA =              0.02, 
                                    analysis_duration =    1000, ######### 2000
                                    pre_zero_pulse =       0,
                                    post_zero_pulse =      0,
                                    analysis_delay =       100,
                                    dt =                   0.025,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  False,
                                    plot_if =              True,
                                    plot_iv =              True,
                                    temperature =          '34degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell axoaxoniccell in ../cells/axoaxonic.cell.nml using jNeuroML_NEURON (-0.1nA->0.4nA; 0.02nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_axoaxoniccell to file: LEMS_iv_axoaxoniccell.xml
# pyNeuroML >>> Generating plot: Firing frequency versus injected current for: ../cells/axoaxonic.cell.nml
# pyNeuroML >>> Generating plot: V at 1100ms versus I below threshold for: ../cells/axoaxonic.cell.nml

# %%
from pyneuroml import pynml
pynml.run_jneuroml("", cell_file, '-png')
from IPython.display import Image
Image(filename=cell_file.replace('.nml','.png'),width=500)
