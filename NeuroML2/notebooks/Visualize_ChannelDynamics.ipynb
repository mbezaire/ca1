# %% [markdown]
# ## Channel dynamics
#
# This notebook helps to visualize the results of the *../channels/analyse_chans.sh* bash script. That script calls [pyNeuroML](https://github.com/NeuroML/pyNeuroML) to create .html and .md summary files and also saves into .dat-files (whose are going to be used here). Author: András Ecker last update: 07.2017
# > Note: constants from the bash script: temperature: 24 degC, internal Ca++ conc: 5e-6 mM, E_rev: 0 mV

# %%
# %autoreload 2
# %matplotlib inline
# Out:
# ERROR:root:Line magic function `%autoreload` not found.

# %% [markdown]
# #### Steady state variables
# * The cell below shows how to visualize inf (or steady state) variables of muliple channels
# > Navbis is a modified version of Nav to have a slightly higher threshold, suitable for bistratified cells

# %%
from helper import plot_inf

chans = ["Nav", "Navbis"]  # has to be a list
plot_inf(chans)

# %% [markdown]
# #### Tau variables
# * The cell below shows how to visualize tau variables of muliple channels
# > Shows the difference between the slow and fast delayed rectifier potassium channel (Kdr)

# %%
from helper import plot_tau

chans = ["Kdrslow", "Kdrfast"]  # has to be a list
plot_tau(chans)
